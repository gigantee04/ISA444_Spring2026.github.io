# %% [markdown]
# <a href="https://colab.research.google.com/github/gigantee04/ISA444_Spring2026.github.io/blob/main/FoundationModelNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##!pip install timecopilot utilsforecast

import pandas as pd
from timecopilot import TimeCopilotForecaster
from timecopilot.models.foundation.chronos import Chronos
from timecopilot.models.foundation.moirai import Moirai
from timecopilot.models.foundation.timesfm import TimesFM

from utilsforecast.evaluation import evaluate
from utilsforecast.losses import mape, rmse, mae, bias
# Out:
#  See https://github.com/google-research/timesfm/blob/master/README.md for updated APIs.

# %%
df = (
    pd.read_parquet("/content/sample_hotels-1.parquet")
    .query("unique_id not in ['hotel_77', 'hotel_28']")
   .assign(
        ds = lambda x: pd.to_datetime(x["ds"]),
        unique_id = lambda x: x["unique_id"].astype(str),
        y = lambda x: x["y"].astype(float),
   )
    [['unique_id', 'ds', 'y']]
)


TimeCopilotForecaster.plot(df, engine='plotly')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="fd454611-a36c-4654-b572-7dcf6dd374db" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fd454611-a36c-4654-b572-7dcf6dd374db")) {                    Plotly.newPlot(                        "fd454611-a36c-4654-b572-7dcf6dd374db",                        [{"legendgroup":"y","line":{"color":"#17becf","width":1},"mode":"lines","name":"y","showlegend":true,"x":["2022-01-01T00:00:00","2022-01-02T00:00:00","2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-08T00:00:00","2022-01-09T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:00","2022-01-13T00:00:00","2022-01-14T00:00:00","2022-01-15T00:00:00","2022-01-16T00:00:00","2022-01-17T00:00:00","2022-01-18T00:00:00","2022-01-19T00:00:00","2022-01-20T00:00:00","2022-01-21T00:00:00","2022-01-22T00:00:00","2022-01-23T00:00:00","2022-01-24T00:00:00","2022-01-25T00:00:00","2022-01-26T00:00:00","2022-01-27T00:00:00","2022-01-28T00:00:00","2022-01-29T00:00:00","2022-01-30T00:00:00","2022-01-31T00:00:00","2022-02-01T00:00:00","2022-02-02T00:00:00","2022-02-03T00:00:00","2022-02-04T00:00:00","2022-02-05T00:00:00","2022-02-06T00:00:00","2022-02-07T00:00:00","2022-02-08T00:00:00","2022-02-09T00:00:00","2022-02-10T00:00:00","2022-02-11T00:00:00","2022-02-12T00:00:00","2022-02-13T00:00:00","2022-02-14T00:00:00","2022-02-15T00:00:00","2022-02-16T00:00:00","2022-02-17T00:00:00","2022-02-18T00:00:00","2022-02-19T00:00:00","2022-02-20T00:00:00","2022-02-21T00:00:00","2022-02-22T00:00:00","2022-02-23T00:00:00","2022-02-24T00:00:00","2022-02-25T00:00:00","2022-02-26T00:00:00","2022-02-27T00:00:00","2022-02-28T00:00:00","2022-03-01T00:00:00","2022-03-02T00:00:00","2022-03-03T00:00:00","2022-03-04T00:00:00","2022-03-05T00:00:00","2022-03-06T00:00:00","2022-03-07T00:00:00","2022-03-08T00:00:00","2022-03-09T00:00:00","2022-03-10T00:00:00","2022-03-11T00:00:00","2022-03-12T00:00:00","2022-03-13T00:00:00","2022-03-14T00:00:00","2022-03-15T00:00:00","2022-03-16T00:00:00","2022-03-17T00:00:00","2022-03-18T00:00:00","2022-03-19T00:00:00","2022-03-20T00:00:00","2022-03-21T00:00:00","2022-03-22T00:00:00","2022-03-23T00:00:00","2022-03-24T00:00:00","2022-03-25T00:00:00","2022-03-26T00:00:00","2022-03-27T00:00:00","2022-03-28T00:00:00","2022-03-29T00:00:00","2022-03-30T00:00:00","2022-03-31T00:00:00","2022-04-01T00:00:00","2022-04-02T00:00:00","2022-04-03T00:00:00","2022-04-04T00:00:00","2022-04-05T00:00:00","2022-04-06T00:00:00","2022-04-07T00:00:00","2022-04-08T00:00:00","2022-04-09T00:00:00","2022-04-10T00:00:00","2022-04-11T00:00:00","2022-04-12T00:00:00","2022-04-13T00:00:00","2022-04-14T00:00:00","2022-04-15T00:00:00","2022-04-16T00:00:00","2022-04-17T00:00:00","2022-04-18T00:00:00","2022-04-19T00:00:00","2022-04-20T00:00:00","2022-04-21T00:00:00","2022-04-22T00:00:00","2022-04-23T00:00:00","2022-04-24T00:00:00","2022-04-25T00:00:00","2022-04-26T00:00:00","2022-04-27T00:00:00","2022-04-28T00:00:00","2022-04-29T00:00:00","2022-04-30T00:00:00","2022-05-01T00:00:00","2022-05-02T00:00:00","2022-05-03T00:00:00","2022-05-04T00:00:00","2022-05-05T00:00:00","2022-05-06T00:00:00","2022-05-07T00:00:00","2022-05-08T00:00:00","2022-05-09T00:00:00","2022-05-10T00:00:00","2022-05-11T00:00:00","2022-05-12T00:00:00","2022-05-13T00:00:00","2022-05-14T00:00:00","2022-05-15T00:00:00","2022-05-16T00:00:00","2022-05-17T00:00:00","2022-05-18T00:00:00","2022-05-19T00:00:00","2022-05-20T00:00:00","2022-05-21T00:00:00","2022-05-22T00:00:00","2022-05-23T00:00:00","2022-05-24T00:00:00","2022-05-25T00:00:00","2022-05-26T00:00:00","2022-05-27T00:00:00","2022-05-28T00:00:00","2022-05-29T00:00:00","2022-05-30T0 ...

# %%
tcf = TimeCopilotForecaster(
    models = [
        Chronos(repo_id="amazon/chronos-bolt-small"),
        Moirai(),
        TimesFM(repo_id="google/timesfm-2.5-200m-pytorch", alias="TimesFM-2.5"),
    ]
)

t_cv = tcf.cross_validation(
    df = df,
    h = 28, freq = 'D',
    n_windows = 12,
    step_size = 28
)
# Out:
# 0it [00:00, ?it/s]
# config.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/191M [00:00<?, ?B/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# 100%|██████████| 2/2 [00:00<00:00,  2.07it/s]
# 1it [00:05,  5.54s/it]
# 100%|██████████| 2/2 [00:00<00:00, 46.41it/s]
# 2it [00:06,  2.67s/it]
# 100%|██████████| 2/2 [00:00<00:00, 42.84it/s]
# 3it [00:06,  1.74s/it]
# 100%|██████████| 2/2 [00:00<00:00, 47.40it/s]
# 4it [00:07,  1.31s/it]
# 100%|██████████| 2/2 [00:00<00:00, 46.75it/s]
# 5it [00:08,  1.07s/it]
# 100%|██████████| 2/2 [00:00<00:00, 46.24it/s]
# 6it [00:08,  1.08it/s]
# 100%|██████████| 2/2 [00:00<00:00, 45.75it/s]
# 7it [00:09,  1.19it/s]
# 100%|██████████| 2/2 [00:00<00:00, 46.87it/s]
# 8it [00:10,  1.28it/s]
# 100%|██████████| 2/2 [00:00<00:00, 47.44it/s]
# 9it [00:10,  1.35it/s]
# 100%|██████████| 2/2 [00:00<00:00, 47.39it/s]
# 10it [00:11,  1.41it/s]
# 100%|██████████| 2/2 [00:00<00:00, 46.80it/s]
# 11it [00:12,  1.44it/s]
# 100%|██████████| 2/2 [00:00<00:00, 46.07it/s]
# 12it [00:12,  1.06s/it]
# 0it [00:00, ?it/s]
# config.json:   0%|          | 0.00/684 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.24G [00:00<?, ?B/s]
# 0it [00:00, ?it/s]
# 17it [00:00, 20.02it/s]
# 1it [00:27, 27.58s/it]
# 0it [00:00, ?it/s]
# 17it [00:00, 26.32it/s]
# 2it [00:31, 13.44s/it]
# 0it [00:00, ?it/s]
# 17it [00:00, 27.65it/s]
# 3it [00:34,  8.85s/it]
# 0it [00:00, ?it/s]
# 17it [00:00, 26.53it/s]
# 4it [00:38,  6.92s/it]
# 0it [00:00, ?it/s]
# 17it [00:00, 28.23it/s]
# 5it [00:41,  5.64s/it]
# 0it [00:00, ?it/s]
# 17it [00:00, 28.42it/s]
# 6it [00:45,  4.87s/it]
# 0it [00:00, ?it/s]
# 17it [00:00, 27.82it/s]
# 7it [00:48,  4.39s/it]
# 0it [00:00, ?it/s]
# 17it [00:00, 27.41it/s]
# 8it [00:52,  4.32s/it]
# 0it [00:00, ?it/s]
# 17it [00:00, 28.96it/s]
# 9it [00:56,  3.99s/it]
# 0it [00:00, ?it/s]
# 17it [00:00, 27.18it/s]
# 10it [00:59,  3.79s/it]
# 0it [00:00, ?it/s]
# 17it [00:00, 26.82it/s]
# 11it [01:03,  3.85s/it]
# 0it [00:00, ?it/s]
# 17it [00:00, 28.22it/s]
# 12it [01:06,  5.56s/it]
# 0it [00:00, ?it/s]
# config.json:   0%|          | 0.00/475 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/925M [00:00<?, ?B/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:03<00:00,  3.74s/it]
# 1it [00:20, 20.96s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:02<00:00,  2.99s/it]
# 2it [00:24, 10.78s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:03<00:00,  3.06s/it]
# 3it [00:28,  7.54s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:03<00:00,  3.69s/it]
# 4it [00:32,  6.26s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:03<00:00,  3.03s/it]
# 5it [00:36,  5.31s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:03<00:00,  3.06s/it]
# 6it [00:39,  4.77s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:03<00:00,  3.31s/it]
# 7it [00:43,  4.49s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:03<00:00,  3.28s/it]
# 8it [00:47,  4.31s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:03<00:00,  3.05s/it]
# 9it [00:51,  4.10s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
# 10it [00:55,  4.00s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:03<00:00,  3.60s/it]
# 11it [00:59,  4.07s/it]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|██████████| 1/1 [00:03<00:00,  3.14s/it]
# 12it [01:03,  5.27s/it]

# %%
eval_transformers = evaluate(
    df = t_cv,
    metrics = [mape, rmse, mae, bias],
    models = ['Chronos', 'Moirai', 'TimesFM-2.5']
)

eval_transformers = eval_transformers.drop(columns=['cutoff']).groupby(['unique_id','metric']).mean().reset_index(inplace=False)
eval_transformers
# Out:
#     unique_id metric   Chronos    Moirai  TimesFM-2.5
# 0     hotel_0   bias  0.058557  0.106858     0.058835
# 1     hotel_0    mae  0.178360  0.193299     0.163652
# 2     hotel_0   mape  0.324892  0.367028     0.298579
# 3     hotel_0   rmse  0.209950  0.229687     0.197826
# 4   hotel_105   bias -0.004458  0.025120     0.008051
# ..        ...    ...       ...       ...          ...
# 63   hotel_91   rmse  0.195977  0.207737     0.194306
# 64   hotel_98   bias -0.016269 -0.041239    -0.040731
# 65   hotel_98    mae  0.130303  0.109430     0.104923
# 66   hotel_98   mape  0.841273  0.606602     0.573925
# 67   hotel_98   rmse  0.170791  0.148703     0.144442
#
# [68 rows x 5 columns]

# %%
# 1. Aggregate to get one row per model per metric (Average across all IDs)
overall_metrics = eval_transformers.groupby('metric').mean(numeric_only=True)

# 2. Identify the "Winner" for each series and each metric
# We find the column name (model) with the minimum value for each row
model_columns = ['Chronos', 'Moirai', 'TimesFM-2.5']
eval_transformers['winner'] = eval_transformers[model_columns].idxmin(axis=1)

# 3. Count how many times each model won
model_wins = eval_transformers.groupby(['metric', 'winner']).size().unstack(fill_value=0)

print("--- Overall Average Metrics ---")
print(overall_metrics)
print("\n--- Model Win Counts ---")
print(model_wins)
# Out:
# --- Overall Average Metrics ---
#          Chronos    Moirai  TimesFM-2.5
# metric
# bias    0.014613  0.023677     0.012900
# mae     0.116723  0.120887     0.111534
# mape    0.330281  0.323508     0.310646
# rmse    0.142160  0.147904     0.137107
#
# --- Model Win Counts ---
# winner  Chronos  Moirai  TimesFM-2.5
# metric
# bias          9       2            6
# mae           4       0           13
# mape          3       1           13
# rmse          3       1           13

# %%
# Generate forecasts for the next 28 days
forecasts_df = tcf.forecast(df=df, h=28, freq='D')

# Export to CSV
forecasts_df.to_csv("final_forecasts.csv", index=False)
print("Forecasts exported to final_forecasts.csv")
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 46.79it/s]
# 17it [00:00, 25.75it/s]
# 100%|██████████| 1/1 [00:03<00:00,  3.23s/it]
# Forecasts exported to final_forecasts.csv

# %%
recent_history = df.groupby('unique_id').tail(60)

TimeCopilotForecaster.plot(
    df=recent_history,
    forecasts_df=forecasts_df,
    models=['Chronos', 'Moirai', 'TimesFM-2.5'],
    engine='plotly',
    max_ids=5
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="ac7dbe27-7ed5-4b14-85d7-1781937124e0" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ac7dbe27-7ed5-4b14-85d7-1781937124e0")) {                    Plotly.newPlot(                        "ac7dbe27-7ed5-4b14-85d7-1781937124e0",                        [{"legendgroup":"y","line":{"color":"#1f77b4","width":1},"mode":"lines","name":"y","showlegend":true,"x":["2023-05-02T00:00:00","2023-05-03T00:00:00","2023-05-04T00:00:00","2023-05-05T00:00:00","2023-05-06T00:00:00","2023-05-07T00:00:00","2023-05-08T00:00:00","2023-05-09T00:00:00","2023-05-10T00:00:00","2023-05-11T00:00:00","2023-05-12T00:00:00","2023-05-13T00:00:00","2023-05-14T00:00:00","2023-05-15T00:00:00","2023-05-16T00:00:00","2023-05-17T00:00:00","2023-05-18T00:00:00","2023-05-19T00:00:00","2023-05-20T00:00:00","2023-05-21T00:00:00","2023-05-22T00:00:00","2023-05-23T00:00:00","2023-05-24T00:00:00","2023-05-25T00:00:00","2023-05-26T00:00:00","2023-05-27T00:00:00","2023-05-28T00:00:00","2023-05-29T00:00:00","2023-05-30T00:00:00","2023-05-31T00:00:00","2023-06-01T00:00:00","2023-06-02T00:00:00","2023-06-03T00:00:00","2023-06-04T00:00:00","2023-06-05T00:00:00","2023-06-06T00:00:00","2023-06-07T00:00:00","2023-06-08T00:00:00","2023-06-09T00:00:00","2023-06-10T00:00:00","2023-06-11T00:00:00","2023-06-12T00:00:00","2023-06-13T00:00:00","2023-06-14T00:00:00","2023-06-15T00:00:00","2023-06-16T00:00:00","2023-06-17T00:00:00","2023-06-18T00:00:00","2023-06-19T00:00:00","2023-06-20T00:00:00","2023-06-21T00:00:00","2023-06-22T00:00:00","2023-06-23T00:00:00","2023-06-24T00:00:00","2023-06-25T00:00:00","2023-06-26T00:00:00","2023-06-27T00:00:00","2023-06-28T00:00:00","2023-06-29T00:00:00","2023-06-30T00:00:00","2023-07-01T00:00:00","2023-07-02T00:00:00","2023-07-03T00:00:00","2023-07-04T00:00:00","2023-07-05T00:00:00","2023-07-06T00:00:00","2023-07-07T00:00:00","2023-07-08T00:00:00","2023-07-09T00:00:00","2023-07-10T00:00:00","2023-07-11T00:00:00","2023-07-12T00:00:00","2023-07-13T00:00:00","2023-07-14T00:00:00","2023-07-15T00:00:00","2023-07-16T00:00:00","2023-07-17T00:00:00","2023-07-18T00:00:00","2023-07-19T00:00:00","2023-07-20T00:00:00","2023-07-21T00:00:00","2023-07-22T00:00:00","2023-07-23T00:00:00","2023-07-24T00:00:00","2023-07-25T00:00:00","2023-07-26T00:00:00","2023-07-27T00:00:00","2023-07-28T00:00:00"],"y":{"dtype":"f8","bdata":"hmAdbd6n6D8qLhmCdbTpPwAAAAAAAPA\u002fAAAAAAAA8D8VlwzBOtrsP7R5n+KSIeg\u002fhmAdbd6n6D+f4pIhWEfrP5\u002fikiFYR+s\u002fcckQrKPN6z8uGYJ1tHnvPwAAAAAAAPA\u002ftHmf4pIh6D8\u002fxSVDsI7mP4ZgHW3ep+g\u002fcckQrKPN6z+5ZAjW0ebtP1wyBOto8+4\u002fFZcMwTra7D\u002fO+xSXDMHqPxWXDME62uw\u002fFZcMwTra7D8AAAAAAADwP1wyBOto8+4\u002fLhmCdbR57z8AAAAAAADwPxWXDME62uw\u002fn+KSIVhH6z9xyRCso83rPwAAAAAAAPA\u002fAAAAAAAA8D8uGYJ1tHnvP2nzPsUlQ\u002fA\u002f532KS4Zg7T+KS4ZgHW3uP1wyBOto8+4\u002fQ7CONu9T7D+KS4ZgHW3uPy4ZgnW0ee8\u002fAAAAAAAA8D8qLhmCdbTpP7lkCNbR5u0\u002fLhmCdbR57z8AAAAAAADwPwAAAAAAAPA\u002fAAAAAAAA8D8AAAAAAADwPy4ZgnW0ee8\u002fXDIE62jz7j+5ZAjW0ebtP5\u002fikiFYR+s\u002f\u002fBSXDME66j+5ZAjW0ebtP2nzPsUlQ\u002fA\u002fQ7CONu9T7D8uGYJ1tHnvPy4ZgnW0ee8\u002fikuGYB1t7j\u002fnfYpLhmDtP1wyBOto8+4\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8AAAAAAAD4fwAAAAAAAPh\u002fAAAAAAAA+H8="},"type":"scatter","xaxis":"x","yaxis":"y"},{"legendgroup":"Chronos","line":{"color":"#d62728","width":1},"mode":"lines","name":"Chronos","showlegend":true,"x":["2023-05-02T00:00:00","2023-05-03T00:00: ...
